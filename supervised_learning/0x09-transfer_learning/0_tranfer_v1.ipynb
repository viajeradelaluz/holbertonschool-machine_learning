# %%
#!/usr/bin/env python3
"""
Trains a convolutional neural network to classify the CIFAR 10 dataset.
"""

import tensorflow as tf
import tensorflow.keras as K  # type: ignore


def preprocess_data(X, Y):
    X_p = K.applications.inception_v3.preprocess_input(X)
    Y_p = K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def train_model():
    # Load the CIFAR-10 dataset
    (X_train, y_train), (X_test, y_test) = K.datasets.cifar10.load_data()

    # Preprocess the data
    X_train, y_train = preprocess_data(X_train, y_train)
    X_test, y_test = preprocess_data(X_test, y_test)

    # Define the base model
    input_tensor = K.layers.Input(shape=(32, 32, 3))
    x = K.layers.Lambda(
        lambda image: tf.image.resize(image, (229, 229)),
    )(input_tensor)
    base_model = K.applications.InceptionV3(
        weights="imagenet", include_top=False, input_tensor=x
    )

    # Freeze the base model layers
    for layer in base_model.layers:
        layer.trainable = False

    # Add the top layers for classification
    x = K.layers.GlobalAveragePooling2D()(base_model.output)
    x = K.layers.Dense(1024, activation="relu")(x)
    predictions = K.layers.Dense(10, activation="softmax")(x)
    model = K.models.Model(inputs=base_model.input, outputs=predictions)

    checkpoint = K.callbacks.ModelCheckpoint(
        "cifar10.h5", monitor="val_accuracy", save_best_only=True
    )

    # Compile the model
    model.compile(
        optimizer=K.optimizers.Adam(learning_rate=2e-5),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )

    # Train the model
    history = model.fit(
        X_train,
        y_train,
        epochs=10,
        batch_size=32,
        validation_data=(X_test, y_test),
        callbacks=[checkpoint],
    )

    # Save the model
    model.summary()
    model.save("cifar10.h5")

    return history

if __name__ == "__main__":
    history = train_model()
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 133s 81ms/step - loss: 0.6167 - accuracy: 0.8057 - val_loss: 0.4552 - val_accuracy: 0.8470
# Epoch 2/10
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.4086 - accuracy: 0.8626 - val_loss: 0.4193 - val_accuracy: 0.8582
# Epoch 3/10
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.3661 - accuracy: 0.8771 - val_loss: 0.4041 - val_accuracy: 0.8625
# Epoch 4/10
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.3387 - accuracy: 0.8866 - val_loss: 0.3958 - val_accuracy: 0.8652
# Epoch 5/10
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.3188 - accuracy: 0.8925 - val_loss: 0.3873 - val_accuracy: 0.8708
# Epoch 6/10
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.2995 - accuracy: 0.9002 - val_loss: 0.3781 - val_accuracy: 0.8722
# Epoch 7/10
# 1563/1563 [==============================] - 123s 79ms/step - loss: 0.2842 - accuracy: 0.9048 - val_loss: 0.3818 - val_accuracy: 0.8712
# Epoch 8/10
# 1563/1563 [==============================] - 123s 79ms/step - loss: 0.2710 - accuracy: 0.9102 - val_loss: 0.3748 - val_accuracy: 0.8736
# Epoch 9/10
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.2571 - accuracy: 0.9144 - val_loss: 0.3722 - val_accuracy: 0.8744
# Epoch 10/10
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.2450 - accuracy: 0.9201 - val_loss: 0.3684 - val_accuracy: 0.8773
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_11 (InputLayer)          [(None, 32, 32, 3)]  0           []
#
#  lambda_10 (Lambda)             (None, 229, 229, 3)  0           ['input_11[0][0]']
#
#  conv2d_940 (Conv2D)            (None, 114, 114, 32  864         ['lambda_10[0][0]']
#                                 )
#
#  batch_normalization_944 (Batch  (None, 114, 114, 32  96         ['conv2d_940[0][0]']
#  Normalization)                 )
#
#  activation_940 (Activation)    (None, 114, 114, 32  0           ['batch_normalization_944[0][0]']
#                                 )
#
#  conv2d_941 (Conv2D)            (None, 112, 112, 32  9216        ['activation_940[0][0]']
#                                 )
#
#  batch_normalization_945 (Batch  (None, 112, 112, 32  96         ['conv2d_941[0][0]']
#  Normalization)                 )
#
#  activation_941 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_945[0][0]']
#                                 )
#
#  conv2d_942 (Conv2D)            (None, 112, 112, 64  18432       ['activation_941[0][0]']
#                                 )
#
#  batch_normalization_946 (Batch  (None, 112, 112, 64  192        ['conv2d_942[0][0]']
#  Normalization)                 )
#
#  activation_942 (Activation)    (None, 112, 112, 64  0           ['batch_normalization_946[0][0]']
#                                 )
#
#  max_pooling2d_40 (MaxPooling2D  (None, 55, 55, 64)  0           ['activation_942[0][0]']
#  )
#
#  conv2d_943 (Conv2D)            (None, 55, 55, 80)   5120        ['max_pooling2d_40[0][0]']
#
#  batch_normalization_947 (Batch  (None, 55, 55, 80)  240         ['conv2d_943[0][0]']
#  Normalization)
#
#  activation_943 (Activation)    (None, 55, 55, 80)   0           ['batch_normalization_947[0][0]']
#
#  conv2d_944 (Conv2D)            (None, 53, 53, 192)  138240      ['activation_943[0][0]']
#
#  batch_normalization_948 (Batch  (None, 53, 53, 192)  576        ['conv2d_944[0][0]']
#  Normalization)
#
#  activation_944 (Activation)    (None, 53, 53, 192)  0           ['batch_normalization_948[0][0]']
#
#  max_pooling2d_41 (MaxPooling2D  (None, 26, 26, 192)  0          ['activation_944[0][0]']
#  )
#
#  conv2d_948 (Conv2D)            (None, 26, 26, 64)   12288       ['max_pooling2d_41[0][0]']
#
#  batch_normalization_952 (Batch  (None, 26, 26, 64)  192         ['conv2d_948[0][0]']
#  Normalization)
#
#  activation_948 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_952[0][0]']
#
#  conv2d_946 (Conv2D)            (None, 26, 26, 48)   9216        ['max_pooling2d_41[0][0]']
#
#  conv2d_949 (Conv2D)            (None, 26, 26, 96)   55296       ['activation_948[0][0]']
#
#  batch_normalization_950 (Batch  (None, 26, 26, 48)  144         ['conv2d_946[0][0]']
#  Normalization)
#
#  batch_normalization_953 (Batch  (None, 26, 26, 96)  288         ['conv2d_949[0][0]']
#  Normalization)
#
#  activation_946 (Activation)    (None, 26, 26, 48)   0           ['batch_normalization_950[0][0]']
#
#  activation_949 (Activation)    (None, 26, 26, 96)   0           ['batch_normalization_953[0][0]']
#
#  average_pooling2d_90 (AverageP  (None, 26, 26, 192)  0          ['max_pooling2d_41[0][0]']
#  ooling2D)
#
#  conv2d_945 (Conv2D)            (None, 26, 26, 64)   12288       ['max_pooling2d_41[0][0]']
#
#  conv2d_947 (Conv2D)            (None, 26, 26, 64)   76800       ['activation_946[0][0]']
#
#  conv2d_950 (Conv2D)            (None, 26, 26, 96)   82944       ['activation_949[0][0]']
#
#  conv2d_951 (Conv2D)            (None, 26, 26, 32)   6144        ['average_pooling2d_90[0][0]']
#
#  batch_normalization_949 (Batch  (None, 26, 26, 64)  192         ['conv2d_945[0][0]']
#  Normalization)
#
#  batch_normalization_951 (Batch  (None, 26, 26, 64)  192         ['conv2d_947[0][0]']
#  Normalization)
#
#  batch_normalization_954 (Batch  (None, 26, 26, 96)  288         ['conv2d_950[0][0]']
#  Normalization)
#
#  batch_normalization_955 (Batch  (None, 26, 26, 32)  96          ['conv2d_951[0][0]']
#  Normalization)
#
#  activation_945 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_949[0][0]']
#
#  activation_947 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_951[0][0]']
#
#  activation_950 (Activation)    (None, 26, 26, 96)   0           ['batch_normalization_954[0][0]']
#
#  activation_951 (Activation)    (None, 26, 26, 32)   0           ['batch_normalization_955[0][0]']
#
#  mixed0 (Concatenate)           (None, 26, 26, 256)  0           ['activation_945[0][0]',
#                                                                   'activation_947[0][0]',
#                                                                   'activation_950[0][0]',
#                                                                   'activation_951[0][0]']
#
#  conv2d_955 (Conv2D)            (None, 26, 26, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_959 (Batch  (None, 26, 26, 64)  192         ['conv2d_955[0][0]']
#  Normalization)
#
#  activation_955 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_959[0][0]']
#
#  conv2d_953 (Conv2D)            (None, 26, 26, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_956 (Conv2D)            (None, 26, 26, 96)   55296       ['activation_955[0][0]']
#
#  batch_normalization_957 (Batch  (None, 26, 26, 48)  144         ['conv2d_953[0][0]']
#  Normalization)
#
#  batch_normalization_960 (Batch  (None, 26, 26, 96)  288         ['conv2d_956[0][0]']
#  Normalization)
#
#  activation_953 (Activation)    (None, 26, 26, 48)   0           ['batch_normalization_957[0][0]']
#
#  activation_956 (Activation)    (None, 26, 26, 96)   0           ['batch_normalization_960[0][0]']
#
#  average_pooling2d_91 (AverageP  (None, 26, 26, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_952 (Conv2D)            (None, 26, 26, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_954 (Conv2D)            (None, 26, 26, 64)   76800       ['activation_953[0][0]']
#
#  conv2d_957 (Conv2D)            (None, 26, 26, 96)   82944       ['activation_956[0][0]']
#
#  conv2d_958 (Conv2D)            (None, 26, 26, 64)   16384       ['average_pooling2d_91[0][0]']
#
#  batch_normalization_956 (Batch  (None, 26, 26, 64)  192         ['conv2d_952[0][0]']
#  Normalization)
#
#  batch_normalization_958 (Batch  (None, 26, 26, 64)  192         ['conv2d_954[0][0]']
#  Normalization)
#
#  batch_normalization_961 (Batch  (None, 26, 26, 96)  288         ['conv2d_957[0][0]']
#  Normalization)
#
#  batch_normalization_962 (Batch  (None, 26, 26, 64)  192         ['conv2d_958[0][0]']
#  Normalization)
#
#  activation_952 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_956[0][0]']
#
#  activation_954 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_958[0][0]']
#
#  activation_957 (Activation)    (None, 26, 26, 96)   0           ['batch_normalization_961[0][0]']
#
#  activation_958 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_962[0][0]']
#
#  mixed1 (Concatenate)           (None, 26, 26, 288)  0           ['activation_952[0][0]',
#                                                                   'activation_954[0][0]',
#                                                                   'activation_957[0][0]',
#                                                                   'activation_958[0][0]']
#
#  conv2d_962 (Conv2D)            (None, 26, 26, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_966 (Batch  (None, 26, 26, 64)  192         ['conv2d_962[0][0]']
#  Normalization)
#
#  activation_962 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_966[0][0]']
#
#  conv2d_960 (Conv2D)            (None, 26, 26, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_963 (Conv2D)            (None, 26, 26, 96)   55296       ['activation_962[0][0]']
#
#  batch_normalization_964 (Batch  (None, 26, 26, 48)  144         ['conv2d_960[0][0]']
#  Normalization)
#
#  batch_normalization_967 (Batch  (None, 26, 26, 96)  288         ['conv2d_963[0][0]']
#  Normalization)
#
#  activation_960 (Activation)    (None, 26, 26, 48)   0           ['batch_normalization_964[0][0]']
#
#  activation_963 (Activation)    (None, 26, 26, 96)   0           ['batch_normalization_967[0][0]']
#
#  average_pooling2d_92 (AverageP  (None, 26, 26, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_959 (Conv2D)            (None, 26, 26, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_961 (Conv2D)            (None, 26, 26, 64)   76800       ['activation_960[0][0]']
#
#  conv2d_964 (Conv2D)            (None, 26, 26, 96)   82944       ['activation_963[0][0]']
#
#  conv2d_965 (Conv2D)            (None, 26, 26, 64)   18432       ['average_pooling2d_92[0][0]']
#
#  batch_normalization_963 (Batch  (None, 26, 26, 64)  192         ['conv2d_959[0][0]']
#  Normalization)
#
#  batch_normalization_965 (Batch  (None, 26, 26, 64)  192         ['conv2d_961[0][0]']
#  Normalization)
#
#  batch_normalization_968 (Batch  (None, 26, 26, 96)  288         ['conv2d_964[0][0]']
#  Normalization)
#
#  batch_normalization_969 (Batch  (None, 26, 26, 64)  192         ['conv2d_965[0][0]']
#  Normalization)
#
#  activation_959 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_963[0][0]']
#
#  activation_961 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_965[0][0]']
#
#  activation_964 (Activation)    (None, 26, 26, 96)   0           ['batch_normalization_968[0][0]']
#
#  activation_965 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_969[0][0]']
#
#  mixed2 (Concatenate)           (None, 26, 26, 288)  0           ['activation_959[0][0]',
#                                                                   'activation_961[0][0]',
#                                                                   'activation_964[0][0]',
#                                                                   'activation_965[0][0]']
#
#  conv2d_967 (Conv2D)            (None, 26, 26, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_971 (Batch  (None, 26, 26, 64)  192         ['conv2d_967[0][0]']
#  Normalization)
#
#  activation_967 (Activation)    (None, 26, 26, 64)   0           ['batch_normalization_971[0][0]']
#
#  conv2d_968 (Conv2D)            (None, 26, 26, 96)   55296       ['activation_967[0][0]']
#
#  batch_normalization_972 (Batch  (None, 26, 26, 96)  288         ['conv2d_968[0][0]']
#  Normalization)
#
#  activation_968 (Activation)    (None, 26, 26, 96)   0           ['batch_normalization_972[0][0]']
#
#  conv2d_966 (Conv2D)            (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_969 (Conv2D)            (None, 12, 12, 96)   82944       ['activation_968[0][0]']
#
#  batch_normalization_970 (Batch  (None, 12, 12, 384)  1152       ['conv2d_966[0][0]']
#  Normalization)
#
#  batch_normalization_973 (Batch  (None, 12, 12, 96)  288         ['conv2d_969[0][0]']
#  Normalization)
#
#  activation_966 (Activation)    (None, 12, 12, 384)  0           ['batch_normalization_970[0][0]']
#
#  activation_969 (Activation)    (None, 12, 12, 96)   0           ['batch_normalization_973[0][0]']
#
#  max_pooling2d_42 (MaxPooling2D  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_966[0][0]',
#                                                                   'activation_969[0][0]',
#                                                                   'max_pooling2d_42[0][0]']
#
#  conv2d_974 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_978 (Batch  (None, 12, 12, 128)  384        ['conv2d_974[0][0]']
#  Normalization)
#
#  activation_974 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_978[0][0]']
#
#  conv2d_975 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_974[0][0]']
#
#  batch_normalization_979 (Batch  (None, 12, 12, 128)  384        ['conv2d_975[0][0]']
#  Normalization)
#
#  activation_975 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_979[0][0]']
#
#  conv2d_971 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_976 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_975[0][0]']
#
#  batch_normalization_975 (Batch  (None, 12, 12, 128)  384        ['conv2d_971[0][0]']
#  Normalization)
#
#  batch_normalization_980 (Batch  (None, 12, 12, 128)  384        ['conv2d_976[0][0]']
#  Normalization)
#
#  activation_971 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_975[0][0]']
#
#  activation_976 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_980[0][0]']
#
#  conv2d_972 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_971[0][0]']
#
#  conv2d_977 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_976[0][0]']
#
#  batch_normalization_976 (Batch  (None, 12, 12, 128)  384        ['conv2d_972[0][0]']
#  Normalization)
#
#  batch_normalization_981 (Batch  (None, 12, 12, 128)  384        ['conv2d_977[0][0]']
#  Normalization)
#
#  activation_972 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_976[0][0]']
#
#  activation_977 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_981[0][0]']
#
#  average_pooling2d_93 (AverageP  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_970 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_973 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_972[0][0]']
#
#  conv2d_978 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_977[0][0]']
#
#  conv2d_979 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_93[0][0]']
#
#  batch_normalization_974 (Batch  (None, 12, 12, 192)  576        ['conv2d_970[0][0]']
#  Normalization)
#
#  batch_normalization_977 (Batch  (None, 12, 12, 192)  576        ['conv2d_973[0][0]']
#  Normalization)
#
#  batch_normalization_982 (Batch  (None, 12, 12, 192)  576        ['conv2d_978[0][0]']
#  Normalization)
#
#  batch_normalization_983 (Batch  (None, 12, 12, 192)  576        ['conv2d_979[0][0]']
#  Normalization)
#
#  activation_970 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_974[0][0]']
#
#  activation_973 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_977[0][0]']
#
#  activation_978 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_982[0][0]']
#
#  activation_979 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_983[0][0]']
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_970[0][0]',
#                                                                   'activation_973[0][0]',
#                                                                   'activation_978[0][0]',
#                                                                   'activation_979[0][0]']
#
#  conv2d_984 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_988 (Batch  (None, 12, 12, 160)  480        ['conv2d_984[0][0]']
#  Normalization)
#
#  activation_984 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_988[0][0]']
#
#  conv2d_985 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_984[0][0]']
#
#  batch_normalization_989 (Batch  (None, 12, 12, 160)  480        ['conv2d_985[0][0]']
#  Normalization)
#
#  activation_985 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_989[0][0]']
#
#  conv2d_981 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_986 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_985[0][0]']
#
#  batch_normalization_985 (Batch  (None, 12, 12, 160)  480        ['conv2d_981[0][0]']
#  Normalization)
#
#  batch_normalization_990 (Batch  (None, 12, 12, 160)  480        ['conv2d_986[0][0]']
#  Normalization)
#
#  activation_981 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_985[0][0]']
#
#  activation_986 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_990[0][0]']
#
#  conv2d_982 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_981[0][0]']
#
#  conv2d_987 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_986[0][0]']
#
#  batch_normalization_986 (Batch  (None, 12, 12, 160)  480        ['conv2d_982[0][0]']
#  Normalization)
#
#  batch_normalization_991 (Batch  (None, 12, 12, 160)  480        ['conv2d_987[0][0]']
#  Normalization)
#
#  activation_982 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_986[0][0]']
#
#  activation_987 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_991[0][0]']
#
#  average_pooling2d_94 (AverageP  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_980 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_983 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_982[0][0]']
#
#  conv2d_988 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_987[0][0]']
#
#  conv2d_989 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_94[0][0]']
#
#  batch_normalization_984 (Batch  (None, 12, 12, 192)  576        ['conv2d_980[0][0]']
#  Normalization)
#
#  batch_normalization_987 (Batch  (None, 12, 12, 192)  576        ['conv2d_983[0][0]']
#  Normalization)
#
#  batch_normalization_992 (Batch  (None, 12, 12, 192)  576        ['conv2d_988[0][0]']
#  Normalization)
#
#  batch_normalization_993 (Batch  (None, 12, 12, 192)  576        ['conv2d_989[0][0]']
#  Normalization)
#
#  activation_980 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_984[0][0]']
#
#  activation_983 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_987[0][0]']
#
#  activation_988 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_992[0][0]']
#
#  activation_989 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_993[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_980[0][0]',
#                                                                   'activation_983[0][0]',
#                                                                   'activation_988[0][0]',
#                                                                   'activation_989[0][0]']
#
#  conv2d_994 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_998 (Batch  (None, 12, 12, 160)  480        ['conv2d_994[0][0]']
#  Normalization)
#
#  activation_994 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_998[0][0]']
#
#  conv2d_995 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_994[0][0]']
#
#  batch_normalization_999 (Batch  (None, 12, 12, 160)  480        ['conv2d_995[0][0]']
#  Normalization)
#
#  activation_995 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_999[0][0]']
#
#  conv2d_991 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_996 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_995[0][0]']
#
#  batch_normalization_995 (Batch  (None, 12, 12, 160)  480        ['conv2d_991[0][0]']
#  Normalization)
#
#  batch_normalization_1000 (Batc  (None, 12, 12, 160)  480        ['conv2d_996[0][0]']
#  hNormalization)
#
#  activation_991 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_995[0][0]']
#
#  activation_996 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_1000[0][0]'
#                                                                  ]
#
#  conv2d_992 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_991[0][0]']
#
#  conv2d_997 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_996[0][0]']
#
#  batch_normalization_996 (Batch  (None, 12, 12, 160)  480        ['conv2d_992[0][0]']
#  Normalization)
#
#  batch_normalization_1001 (Batc  (None, 12, 12, 160)  480        ['conv2d_997[0][0]']
#  hNormalization)
#
#  activation_992 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_996[0][0]']
#
#  activation_997 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_1001[0][0]'
#                                                                  ]
#
#  average_pooling2d_95 (AverageP  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_990 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_993 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_992[0][0]']
#
#  conv2d_998 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_997[0][0]']
#
# ...
#                                                                  ]
#
#  conv2d_1018 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1017[0][0]']
#
#  conv2d_1019 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1017[0][0]']
#
#  conv2d_1022 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1021[0][0]']
#
#  conv2d_1023 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1021[0][0]']
#
#  average_pooling2d_97 (AverageP  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_1016 (Conv2D)           (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_1022 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1018[0][0]']
#  hNormalization)
#
#  batch_normalization_1023 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1019[0][0]']
#  hNormalization)
#
#  batch_normalization_1026 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1022[0][0]']
#  hNormalization)
#
#  batch_normalization_1027 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1023[0][0]']
#  hNormalization)
#
#  conv2d_1024 (Conv2D)           (None, 5, 5, 192)    245760      ['average_pooling2d_97[0][0]']
#
#  batch_normalization_1020 (Batc  (None, 5, 5, 320)   960         ['conv2d_1016[0][0]']
#  hNormalization)
#
#  activation_1018 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1022[0][0]'
#                                                                  ]
#
#  activation_1019 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1023[0][0]'
#                                                                  ]
#
#  activation_1022 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1026[0][0]'
#                                                                  ]
#
#  activation_1023 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1027[0][0]'
#                                                                  ]
#
#  batch_normalization_1028 (Batc  (None, 5, 5, 192)   576         ['conv2d_1024[0][0]']
#  hNormalization)
#
#  activation_1016 (Activation)   (None, 5, 5, 320)    0           ['batch_normalization_1020[0][0]'
#                                                                  ]
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_1018[0][0]',
#                                                                   'activation_1019[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 5, 5, 768)    0           ['activation_1022[0][0]',
#                                                                   'activation_1023[0][0]']
#
#  activation_1024 (Activation)   (None, 5, 5, 192)    0           ['batch_normalization_1028[0][0]'
#                                                                  ]
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_1016[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'activation_1024[0][0]']
#
#  conv2d_1029 (Conv2D)           (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_1033 (Batc  (None, 5, 5, 448)   1344        ['conv2d_1029[0][0]']
#  hNormalization)
#
#  activation_1029 (Activation)   (None, 5, 5, 448)    0           ['batch_normalization_1033[0][0]'
#                                                                  ]
#
#  conv2d_1026 (Conv2D)           (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_1030 (Conv2D)           (None, 5, 5, 384)    1548288     ['activation_1029[0][0]']
#
#  batch_normalization_1030 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1026[0][0]']
#  hNormalization)
#
#  batch_normalization_1034 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1030[0][0]']
#  hNormalization)
#
#  activation_1026 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1030[0][0]'
#                                                                  ]
#
#  activation_1030 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1034[0][0]'
#                                                                  ]
#
#  conv2d_1027 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1026[0][0]']
#
#  conv2d_1028 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1026[0][0]']
#
#  conv2d_1031 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1030[0][0]']
#
#  conv2d_1032 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1030[0][0]']
#
#  average_pooling2d_98 (AverageP  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_1025 (Conv2D)           (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_1031 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1027[0][0]']
#  hNormalization)
#
#  batch_normalization_1032 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1028[0][0]']
#  hNormalization)
#
#  batch_normalization_1035 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1031[0][0]']
#  hNormalization)
#
#  batch_normalization_1036 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1032[0][0]']
#  hNormalization)
#
#  conv2d_1033 (Conv2D)           (None, 5, 5, 192)    393216      ['average_pooling2d_98[0][0]']
#
#  batch_normalization_1029 (Batc  (None, 5, 5, 320)   960         ['conv2d_1025[0][0]']
#  hNormalization)
#
#  activation_1027 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1031[0][0]'
#                                                                  ]
#
#  activation_1028 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1032[0][0]'
#                                                                  ]
#
#  activation_1031 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1035[0][0]'
#                                                                  ]
#
#  activation_1032 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1036[0][0]'
#                                                                  ]
#
#  batch_normalization_1037 (Batc  (None, 5, 5, 192)   576         ['conv2d_1033[0][0]']
#  hNormalization)
#
#  activation_1025 (Activation)   (None, 5, 5, 320)    0           ['batch_normalization_1029[0][0]'
#                                                                  ]
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_1027[0][0]',
#                                                                   'activation_1028[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 5, 5, 768)    0           ['activation_1031[0][0]',
#                                                                   'activation_1032[0][0]']
#
#  activation_1033 (Activation)   (None, 5, 5, 192)    0           ['batch_normalization_1037[0][0]'
#                                                                  ]
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_1025[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_21[0][0]',
#                                                                   'activation_1033[0][0]']
#
#  global_average_pooling2d_9 (Gl  (None, 2048)        0           ['mixed10[0][0]']
#  obalAveragePooling2D)
#
#  dense_20 (Dense)               (None, 1024)         2098176     ['global_average_pooling2d_9[0][0
#                                                                  ]']
#
#  dense_21 (Dense)               (None, 10)           10250       ['dense_20[0][0]']
#
# ==================================================================================================
# Total params: 23,911,210
# Trainable params: 2,108,426
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# to fix issue with saving keras applications
K.learning_phase = K.backend.learning_phase

_, (X, Y) = K.datasets.cifar10.load_data()
X_p, Y_p = preprocess_data(X, Y)
model = K.models.load_model("cifar10.h5")
model.evaluate(X_p, Y_p, batch_size=128, verbose=1)
# Out:
# 79/79 [==============================] - 22s 223ms/step - loss: 0.3684 - accuracy: 0.8773
# [0.368449330329895, 0.8773000240325928]

# %%
import matplotlib.pyplot as plt


# Plot the training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot the training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
