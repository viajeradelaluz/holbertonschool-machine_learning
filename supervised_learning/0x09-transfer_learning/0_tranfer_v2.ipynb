# %%
#!/usr/bin/env python3
"""
Trains a convolutional neural network to classify the CIFAR 10 dataset.
"""

import tensorflow as tf
import tensorflow.keras as K  # type: ignore


def preprocess_data(X, Y):
    X_p = K.applications.inception_v3.preprocess_input(X)
    Y_p = K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def train_model():
    # Load the CIFAR-10 dataset
    (X_train, y_train), (X_test, y_test) = K.datasets.cifar10.load_data()

    # Preprocess the data
    X_train, y_train = preprocess_data(X_train, y_train)
    X_test, y_test = preprocess_data(X_test, y_test)

    # Define the base model
    input_tensor = K.layers.Input(shape=(32, 32, 3))
    x = K.layers.Lambda(
        lambda image: tf.image.resize(image, (224, 224)),
    )(input_tensor)
    base_model = K.applications.InceptionV3(
        weights="imagenet", include_top=False, input_tensor=x
    )

    # Freeze the base model layers
    for layer in base_model.layers[:384]:
        layer.trainable = False

    # Add the top layers for classification
    x = K.layers.GlobalAveragePooling2D()(base_model.output)
    x = K.layers.Dense(1024, activation="relu")(x)
    predictions = K.layers.Dense(10, activation="softmax")(x)
    model = K.models.Model(inputs=base_model.input, outputs=predictions)

    checkpoint = K.callbacks.ModelCheckpoint(
        "cifar10.h5", monitor="val_accuracy", save_best_only=True
    )

    # Compile the model
    model.compile(
        optimizer=K.optimizers.Adam(learning_rate=2e-5),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )

    # Train the model
    history = model.fit(
        X_train,
        y_train,
        epochs=10,
        batch_size=32,
        validation_data=(X_test, y_test),
        callbacks=[checkpoint],
    )

    # Save the model
    model.summary()
    model.save("cifar10.h5")

    return history

if __name__ == "__main__":
    history = train_model()
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 173s 82ms/step - loss: 0.5973 - accuracy: 0.8126 - val_loss: 0.4417 - val_accuracy: 0.8520
# Epoch 2/10
# 1563/1563 [==============================] - 126s 81ms/step - loss: 0.3942 - accuracy: 0.8667 - val_loss: 0.4170 - val_accuracy: 0.8554
# Epoch 3/10
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.3540 - accuracy: 0.8797 - val_loss: 0.3934 - val_accuracy: 0.8652
# Epoch 4/10
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.3282 - accuracy: 0.8887 - val_loss: 0.3787 - val_accuracy: 0.8724
# Epoch 5/10
# 1563/1563 [==============================] - 126s 81ms/step - loss: 0.3077 - accuracy: 0.8951 - val_loss: 0.3766 - val_accuracy: 0.8729
# Epoch 6/10
# 1563/1563 [==============================] - 126s 81ms/step - loss: 0.2901 - accuracy: 0.9025 - val_loss: 0.3735 - val_accuracy: 0.8733
# Epoch 7/10
# 1563/1563 [==============================] - 125s 80ms/step - loss: 0.2747 - accuracy: 0.9081 - val_loss: 0.3727 - val_accuracy: 0.8729
# Epoch 8/10
# 1563/1563 [==============================] - 125s 80ms/step - loss: 0.2620 - accuracy: 0.9129 - val_loss: 0.3747 - val_accuracy: 0.8740
# Epoch 9/10
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.2495 - accuracy: 0.9168 - val_loss: 0.3647 - val_accuracy: 0.8772
# Epoch 10/10
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.2368 - accuracy: 0.9220 - val_loss: 0.3574 - val_accuracy: 0.8823
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 32, 32, 3)]  0           []
#
#  lambda_10 (Lambda)             (None, 224, 224, 3)  0           ['input_12[0][0]']
#
#  conv2d_967 (Conv2D)            (None, 111, 111, 32  864         ['lambda_10[0][0]']
#                                 )
#
#  batch_normalization_966 (Batch  (None, 111, 111, 32  96         ['conv2d_967[0][0]']
#  Normalization)                 )
#
#  activation_966 (Activation)    (None, 111, 111, 32  0           ['batch_normalization_966[0][0]']
#                                 )
#
#  conv2d_968 (Conv2D)            (None, 109, 109, 32  9216        ['activation_966[0][0]']
#                                 )
#
#  batch_normalization_967 (Batch  (None, 109, 109, 32  96         ['conv2d_968[0][0]']
#  Normalization)                 )
#
#  activation_967 (Activation)    (None, 109, 109, 32  0           ['batch_normalization_967[0][0]']
#                                 )
#
#  conv2d_969 (Conv2D)            (None, 109, 109, 64  18432       ['activation_967[0][0]']
#                                 )
#
#  batch_normalization_968 (Batch  (None, 109, 109, 64  192        ['conv2d_969[0][0]']
#  Normalization)                 )
#
#  activation_968 (Activation)    (None, 109, 109, 64  0           ['batch_normalization_968[0][0]']
#                                 )
#
#  max_pooling2d_42 (MaxPooling2D  (None, 54, 54, 64)  0           ['activation_968[0][0]']
#  )
#
#  conv2d_970 (Conv2D)            (None, 54, 54, 80)   5120        ['max_pooling2d_42[0][0]']
#
#  batch_normalization_969 (Batch  (None, 54, 54, 80)  240         ['conv2d_970[0][0]']
#  Normalization)
#
#  activation_969 (Activation)    (None, 54, 54, 80)   0           ['batch_normalization_969[0][0]']
#
#  conv2d_971 (Conv2D)            (None, 52, 52, 192)  138240      ['activation_969[0][0]']
#
#  batch_normalization_970 (Batch  (None, 52, 52, 192)  576        ['conv2d_971[0][0]']
#  Normalization)
#
#  activation_970 (Activation)    (None, 52, 52, 192)  0           ['batch_normalization_970[0][0]']
#
#  max_pooling2d_43 (MaxPooling2D  (None, 25, 25, 192)  0          ['activation_970[0][0]']
#  )
#
#  conv2d_975 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_43[0][0]']
#
#  batch_normalization_974 (Batch  (None, 25, 25, 64)  192         ['conv2d_975[0][0]']
#  Normalization)
#
#  activation_974 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_974[0][0]']
#
#  conv2d_973 (Conv2D)            (None, 25, 25, 48)   9216        ['max_pooling2d_43[0][0]']
#
#  conv2d_976 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_974[0][0]']
#
#  batch_normalization_972 (Batch  (None, 25, 25, 48)  144         ['conv2d_973[0][0]']
#  Normalization)
#
#  batch_normalization_975 (Batch  (None, 25, 25, 96)  288         ['conv2d_976[0][0]']
#  Normalization)
#
#  activation_972 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_972[0][0]']
#
#  activation_975 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_975[0][0]']
#
#  average_pooling2d_93 (AverageP  (None, 25, 25, 192)  0          ['max_pooling2d_43[0][0]']
#  ooling2D)
#
#  conv2d_972 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_43[0][0]']
#
#  conv2d_974 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_972[0][0]']
#
#  conv2d_977 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_975[0][0]']
#
#  conv2d_978 (Conv2D)            (None, 25, 25, 32)   6144        ['average_pooling2d_93[0][0]']
#
#  batch_normalization_971 (Batch  (None, 25, 25, 64)  192         ['conv2d_972[0][0]']
#  Normalization)
#
#  batch_normalization_973 (Batch  (None, 25, 25, 64)  192         ['conv2d_974[0][0]']
#  Normalization)
#
#  batch_normalization_976 (Batch  (None, 25, 25, 96)  288         ['conv2d_977[0][0]']
#  Normalization)
#
#  batch_normalization_977 (Batch  (None, 25, 25, 32)  96          ['conv2d_978[0][0]']
#  Normalization)
#
#  activation_971 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_971[0][0]']
#
#  activation_973 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_973[0][0]']
#
#  activation_976 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_976[0][0]']
#
#  activation_977 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_977[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_971[0][0]',
#                                                                   'activation_973[0][0]',
#                                                                   'activation_976[0][0]',
#                                                                   'activation_977[0][0]']
#
#  conv2d_982 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_981 (Batch  (None, 25, 25, 64)  192         ['conv2d_982[0][0]']
#  Normalization)
#
#  activation_981 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_981[0][0]']
#
#  conv2d_980 (Conv2D)            (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_983 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_981[0][0]']
#
#  batch_normalization_979 (Batch  (None, 25, 25, 48)  144         ['conv2d_980[0][0]']
#  Normalization)
#
#  batch_normalization_982 (Batch  (None, 25, 25, 96)  288         ['conv2d_983[0][0]']
#  Normalization)
#
#  activation_979 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_979[0][0]']
#
#  activation_982 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_982[0][0]']
#
#  average_pooling2d_94 (AverageP  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_979 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_981 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_979[0][0]']
#
#  conv2d_984 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_982[0][0]']
#
#  conv2d_985 (Conv2D)            (None, 25, 25, 64)   16384       ['average_pooling2d_94[0][0]']
#
#  batch_normalization_978 (Batch  (None, 25, 25, 64)  192         ['conv2d_979[0][0]']
#  Normalization)
#
#  batch_normalization_980 (Batch  (None, 25, 25, 64)  192         ['conv2d_981[0][0]']
#  Normalization)
#
#  batch_normalization_983 (Batch  (None, 25, 25, 96)  288         ['conv2d_984[0][0]']
#  Normalization)
#
#  batch_normalization_984 (Batch  (None, 25, 25, 64)  192         ['conv2d_985[0][0]']
#  Normalization)
#
#  activation_978 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_978[0][0]']
#
#  activation_980 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_980[0][0]']
#
#  activation_983 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_983[0][0]']
#
#  activation_984 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_984[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_978[0][0]',
#                                                                   'activation_980[0][0]',
#                                                                   'activation_983[0][0]',
#                                                                   'activation_984[0][0]']
#
#  conv2d_989 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_988 (Batch  (None, 25, 25, 64)  192         ['conv2d_989[0][0]']
#  Normalization)
#
#  activation_988 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_988[0][0]']
#
#  conv2d_987 (Conv2D)            (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_990 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_988[0][0]']
#
#  batch_normalization_986 (Batch  (None, 25, 25, 48)  144         ['conv2d_987[0][0]']
#  Normalization)
#
#  batch_normalization_989 (Batch  (None, 25, 25, 96)  288         ['conv2d_990[0][0]']
#  Normalization)
#
#  activation_986 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_986[0][0]']
#
#  activation_989 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_989[0][0]']
#
#  average_pooling2d_95 (AverageP  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_986 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_988 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_986[0][0]']
#
#  conv2d_991 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_989[0][0]']
#
#  conv2d_992 (Conv2D)            (None, 25, 25, 64)   18432       ['average_pooling2d_95[0][0]']
#
#  batch_normalization_985 (Batch  (None, 25, 25, 64)  192         ['conv2d_986[0][0]']
#  Normalization)
#
#  batch_normalization_987 (Batch  (None, 25, 25, 64)  192         ['conv2d_988[0][0]']
#  Normalization)
#
#  batch_normalization_990 (Batch  (None, 25, 25, 96)  288         ['conv2d_991[0][0]']
#  Normalization)
#
#  batch_normalization_991 (Batch  (None, 25, 25, 64)  192         ['conv2d_992[0][0]']
#  Normalization)
#
#  activation_985 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_985[0][0]']
#
#  activation_987 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_987[0][0]']
#
#  activation_990 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_990[0][0]']
#
#  activation_991 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_991[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_985[0][0]',
#                                                                   'activation_987[0][0]',
#                                                                   'activation_990[0][0]',
#                                                                   'activation_991[0][0]']
#
#  conv2d_994 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_993 (Batch  (None, 25, 25, 64)  192         ['conv2d_994[0][0]']
#  Normalization)
#
#  activation_993 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_993[0][0]']
#
#  conv2d_995 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_993[0][0]']
#
#  batch_normalization_994 (Batch  (None, 25, 25, 96)  288         ['conv2d_995[0][0]']
#  Normalization)
#
#  activation_994 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_994[0][0]']
#
#  conv2d_993 (Conv2D)            (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_996 (Conv2D)            (None, 12, 12, 96)   82944       ['activation_994[0][0]']
#
#  batch_normalization_992 (Batch  (None, 12, 12, 384)  1152       ['conv2d_993[0][0]']
#  Normalization)
#
#  batch_normalization_995 (Batch  (None, 12, 12, 96)  288         ['conv2d_996[0][0]']
#  Normalization)
#
#  activation_992 (Activation)    (None, 12, 12, 384)  0           ['batch_normalization_992[0][0]']
#
#  activation_995 (Activation)    (None, 12, 12, 96)   0           ['batch_normalization_995[0][0]']
#
#  max_pooling2d_44 (MaxPooling2D  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_992[0][0]',
#                                                                   'activation_995[0][0]',
#                                                                   'max_pooling2d_44[0][0]']
#
#  conv2d_1001 (Conv2D)           (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_1000 (Batc  (None, 12, 12, 128)  384        ['conv2d_1001[0][0]']
#  hNormalization)
#
#  activation_1000 (Activation)   (None, 12, 12, 128)  0           ['batch_normalization_1000[0][0]'
#                                                                  ]
#
#  conv2d_1002 (Conv2D)           (None, 12, 12, 128)  114688      ['activation_1000[0][0]']
#
#  batch_normalization_1001 (Batc  (None, 12, 12, 128)  384        ['conv2d_1002[0][0]']
#  hNormalization)
#
#  activation_1001 (Activation)   (None, 12, 12, 128)  0           ['batch_normalization_1001[0][0]'
#                                                                  ]
#
#  conv2d_998 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_1003 (Conv2D)           (None, 12, 12, 128)  114688      ['activation_1001[0][0]']
#
#  batch_normalization_997 (Batch  (None, 12, 12, 128)  384        ['conv2d_998[0][0]']
#  Normalization)
#
#  batch_normalization_1002 (Batc  (None, 12, 12, 128)  384        ['conv2d_1003[0][0]']
#  hNormalization)
#
#  activation_997 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_997[0][0]']
#
#  activation_1002 (Activation)   (None, 12, 12, 128)  0           ['batch_normalization_1002[0][0]'
#                                                                  ]
#
#  conv2d_999 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_997[0][0]']
#
#  conv2d_1004 (Conv2D)           (None, 12, 12, 128)  114688      ['activation_1002[0][0]']
#
#  batch_normalization_998 (Batch  (None, 12, 12, 128)  384        ['conv2d_999[0][0]']
#  Normalization)
#
#  batch_normalization_1003 (Batc  (None, 12, 12, 128)  384        ['conv2d_1004[0][0]']
#  hNormalization)
#
#  activation_998 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_998[0][0]']
#
#  activation_1003 (Activation)   (None, 12, 12, 128)  0           ['batch_normalization_1003[0][0]'
#                                                                  ]
#
#  average_pooling2d_96 (AverageP  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_997 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_1000 (Conv2D)           (None, 12, 12, 192)  172032      ['activation_998[0][0]']
#
#  conv2d_1005 (Conv2D)           (None, 12, 12, 192)  172032      ['activation_1003[0][0]']
#
#  conv2d_1006 (Conv2D)           (None, 12, 12, 192)  147456      ['average_pooling2d_96[0][0]']
#
#  batch_normalization_996 (Batch  (None, 12, 12, 192)  576        ['conv2d_997[0][0]']
#  Normalization)
#
#  batch_normalization_999 (Batch  (None, 12, 12, 192)  576        ['conv2d_1000[0][0]']
#  Normalization)
#
#  batch_normalization_1004 (Batc  (None, 12, 12, 192)  576        ['conv2d_1005[0][0]']
#  hNormalization)
#
#  batch_normalization_1005 (Batc  (None, 12, 12, 192)  576        ['conv2d_1006[0][0]']
#  hNormalization)
#
#  activation_996 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_996[0][0]']
#
#  activation_999 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_999[0][0]']
#
#  activation_1004 (Activation)   (None, 12, 12, 192)  0           ['batch_normalization_1004[0][0]'
#                                                                  ]
#
#  activation_1005 (Activation)   (None, 12, 12, 192)  0           ['batch_normalization_1005[0][0]'
#                                                                  ]
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_996[0][0]',
#                                                                   'activation_999[0][0]',
#                                                                   'activation_1004[0][0]',
#                                                                   'activation_1005[0][0]']
#
#  conv2d_1011 (Conv2D)           (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_1010 (Batc  (None, 12, 12, 160)  480        ['conv2d_1011[0][0]']
#  hNormalization)
#
#  activation_1010 (Activation)   (None, 12, 12, 160)  0           ['batch_normalization_1010[0][0]'
#                                                                  ]
#
#  conv2d_1012 (Conv2D)           (None, 12, 12, 160)  179200      ['activation_1010[0][0]']
#
#  batch_normalization_1011 (Batc  (None, 12, 12, 160)  480        ['conv2d_1012[0][0]']
#  hNormalization)
#
#  activation_1011 (Activation)   (None, 12, 12, 160)  0           ['batch_normalization_1011[0][0]'
#                                                                  ]
#
#  conv2d_1008 (Conv2D)           (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_1013 (Conv2D)           (None, 12, 12, 160)  179200      ['activation_1011[0][0]']
#
#  batch_normalization_1007 (Batc  (None, 12, 12, 160)  480        ['conv2d_1008[0][0]']
#  hNormalization)
#
#  batch_normalization_1012 (Batc  (None, 12, 12, 160)  480        ['conv2d_1013[0][0]']
#  hNormalization)
#
#  activation_1007 (Activation)   (None, 12, 12, 160)  0           ['batch_normalization_1007[0][0]'
#                                                                  ]
#
#  activation_1012 (Activation)   (None, 12, 12, 160)  0           ['batch_normalization_1012[0][0]'
#                                                                  ]
#
#  conv2d_1009 (Conv2D)           (None, 12, 12, 160)  179200      ['activation_1007[0][0]']
#
#  conv2d_1014 (Conv2D)           (None, 12, 12, 160)  179200      ['activation_1012[0][0]']
#
#  batch_normalization_1008 (Batc  (None, 12, 12, 160)  480        ['conv2d_1009[0][0]']
#  hNormalization)
#
#  batch_normalization_1013 (Batc  (None, 12, 12, 160)  480        ['conv2d_1014[0][0]']
#  hNormalization)
#
#  activation_1008 (Activation)   (None, 12, 12, 160)  0           ['batch_normalization_1008[0][0]'
#                                                                  ]
#
#  activation_1013 (Activation)   (None, 12, 12, 160)  0           ['batch_normalization_1013[0][0]'
#                                                                  ]
#
#  average_pooling2d_97 (AverageP  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_1007 (Conv2D)           (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_1010 (Conv2D)           (None, 12, 12, 192)  215040      ['activation_1008[0][0]']
#
#  conv2d_1015 (Conv2D)           (None, 12, 12, 192)  215040      ['activation_1013[0][0]']
#
#  conv2d_1016 (Conv2D)           (None, 12, 12, 192)  147456      ['average_pooling2d_97[0][0]']
#
#  batch_normalization_1006 (Batc  (None, 12, 12, 192)  576        ['conv2d_1007[0][0]']
#  hNormalization)
#
#  batch_normalization_1009 (Batc  (None, 12, 12, 192)  576        ['conv2d_1010[0][0]']
#  hNormalization)
#
#  batch_normalization_1014 (Batc  (None, 12, 12, 192)  576        ['conv2d_1015[0][0]']
#  hNormalization)
#
#  batch_normalization_1015 (Batc  (None, 12, 12, 192)  576        ['conv2d_1016[0][0]']
#  hNormalization)
#
#  activation_1006 (Activation)   (None, 12, 12, 192)  0           ['batch_normalization_1006[0][0]'
#                                                                  ]
#
#  activation_1009 (Activation)   (None, 12, 12, 192)  0           ['batch_normalization_1009[0][0]'
#                                                                  ]
#
#  activation_1014 (Activation)   (None, 12, 12, 192)  0           ['batch_normalization_1014[0][0]'
#                                                                  ]
#
#  activation_1015 (Activation)   (None, 12, 12, 192)  0           ['batch_normalization_1015[0][0]'
#                                                                  ]
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_1006[0][0]',
#                                                                   'activation_1009[0][0]',
#                                                                   'activation_1014[0][0]',
#                                                                   'activation_1015[0][0]']
#
#  conv2d_1021 (Conv2D)           (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_1020 (Batc  (None, 12, 12, 160)  480        ['conv2d_1021[0][0]']
#  hNormalization)
#
#  activation_1020 (Activation)   (None, 12, 12, 160)  0           ['batch_normalization_1020[0][0]'
#                                                                  ]
#
#  conv2d_1022 (Conv2D)           (None, 12, 12, 160)  179200      ['activation_1020[0][0]']
#
#  batch_normalization_1021 (Batc  (None, 12, 12, 160)  480        ['conv2d_1022[0][0]']
#  hNormalization)
#
#  activation_1021 (Activation)   (None, 12, 12, 160)  0           ['batch_normalization_1021[0][0]'
#                                                                  ]
#
#  conv2d_1018 (Conv2D)           (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_1023 (Conv2D)           (None, 12, 12, 160)  179200      ['activation_1021[0][0]']
#
#  batch_normalization_1017 (Batc  (None, 12, 12, 160)  480        ['conv2d_1018[0][0]']
#  hNormalization)
#
#  batch_normalization_1022 (Batc  (None, 12, 12, 160)  480        ['conv2d_1023[0][0]']
#  hNormalization)
#
#  activation_1017 (Activation)   (None, 12, 12, 160)  0           ['batch_normalization_1017[0][0]'
#                                                                  ]
#
#  activation_1022 (Activation)   (None, 12, 12, 160)  0           ['batch_normalization_1022[0][0]'
#                                                                  ]
#
#  conv2d_1019 (Conv2D)           (None, 12, 12, 160)  179200      ['activation_1017[0][0]']
#
#  conv2d_1024 (Conv2D)           (None, 12, 12, 160)  179200      ['activation_1022[0][0]']
#
#  batch_normalization_1018 (Batc  (None, 12, 12, 160)  480        ['conv2d_1019[0][0]']
# ...
#                                                                  ]
#
#  conv2d_1045 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1043[0][0]']
#
#  conv2d_1046 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1043[0][0]']
#
#  conv2d_1049 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1047[0][0]']
#
#  conv2d_1050 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1047[0][0]']
#
#  average_pooling2d_100 (Average  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  Pooling2D)
#
#  conv2d_1043 (Conv2D)           (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_1044 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1045[0][0]']
#  hNormalization)
#
#  batch_normalization_1045 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1046[0][0]']
#  hNormalization)
#
#  batch_normalization_1048 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1049[0][0]']
#  hNormalization)
#
#  batch_normalization_1049 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1050[0][0]']
#  hNormalization)
#
#  conv2d_1051 (Conv2D)           (None, 5, 5, 192)    245760      ['average_pooling2d_100[0][0]']
#
#  batch_normalization_1042 (Batc  (None, 5, 5, 320)   960         ['conv2d_1043[0][0]']
#  hNormalization)
#
#  activation_1044 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1044[0][0]'
#                                                                  ]
#
#  activation_1045 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1045[0][0]'
#                                                                  ]
#
#  activation_1048 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1048[0][0]'
#                                                                  ]
#
#  activation_1049 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1049[0][0]'
#                                                                  ]
#
#  batch_normalization_1050 (Batc  (None, 5, 5, 192)   576         ['conv2d_1051[0][0]']
#  hNormalization)
#
#  activation_1042 (Activation)   (None, 5, 5, 320)    0           ['batch_normalization_1042[0][0]'
#                                                                  ]
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_1044[0][0]',
#                                                                   'activation_1045[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 5, 5, 768)    0           ['activation_1048[0][0]',
#                                                                   'activation_1049[0][0]']
#
#  activation_1050 (Activation)   (None, 5, 5, 192)    0           ['batch_normalization_1050[0][0]'
#                                                                  ]
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_1042[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'activation_1050[0][0]']
#
#  conv2d_1056 (Conv2D)           (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_1055 (Batc  (None, 5, 5, 448)   1344        ['conv2d_1056[0][0]']
#  hNormalization)
#
#  activation_1055 (Activation)   (None, 5, 5, 448)    0           ['batch_normalization_1055[0][0]'
#                                                                  ]
#
#  conv2d_1053 (Conv2D)           (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_1057 (Conv2D)           (None, 5, 5, 384)    1548288     ['activation_1055[0][0]']
#
#  batch_normalization_1052 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1053[0][0]']
#  hNormalization)
#
#  batch_normalization_1056 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1057[0][0]']
#  hNormalization)
#
#  activation_1052 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1052[0][0]'
#                                                                  ]
#
#  activation_1056 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1056[0][0]'
#                                                                  ]
#
#  conv2d_1054 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1052[0][0]']
#
#  conv2d_1055 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1052[0][0]']
#
#  conv2d_1058 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1056[0][0]']
#
#  conv2d_1059 (Conv2D)           (None, 5, 5, 384)    442368      ['activation_1056[0][0]']
#
#  average_pooling2d_101 (Average  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  Pooling2D)
#
#  conv2d_1052 (Conv2D)           (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_1053 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1054[0][0]']
#  hNormalization)
#
#  batch_normalization_1054 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1055[0][0]']
#  hNormalization)
#
#  batch_normalization_1057 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1058[0][0]']
#  hNormalization)
#
#  batch_normalization_1058 (Batc  (None, 5, 5, 384)   1152        ['conv2d_1059[0][0]']
#  hNormalization)
#
#  conv2d_1060 (Conv2D)           (None, 5, 5, 192)    393216      ['average_pooling2d_101[0][0]']
#
#  batch_normalization_1051 (Batc  (None, 5, 5, 320)   960         ['conv2d_1052[0][0]']
#  hNormalization)
#
#  activation_1053 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1053[0][0]'
#                                                                  ]
#
#  activation_1054 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1054[0][0]'
#                                                                  ]
#
#  activation_1057 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1057[0][0]'
#                                                                  ]
#
#  activation_1058 (Activation)   (None, 5, 5, 384)    0           ['batch_normalization_1058[0][0]'
#                                                                  ]
#
#  batch_normalization_1059 (Batc  (None, 5, 5, 192)   576         ['conv2d_1060[0][0]']
#  hNormalization)
#
#  activation_1051 (Activation)   (None, 5, 5, 320)    0           ['batch_normalization_1051[0][0]'
#                                                                  ]
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_1053[0][0]',
#                                                                   'activation_1054[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 5, 5, 768)    0           ['activation_1057[0][0]',
#                                                                   'activation_1058[0][0]']
#
#  activation_1059 (Activation)   (None, 5, 5, 192)    0           ['batch_normalization_1059[0][0]'
#                                                                  ]
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_1051[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_21[0][0]',
#                                                                   'activation_1059[0][0]']
#
#  global_average_pooling2d_10 (G  (None, 2048)        0           ['mixed10[0][0]']
#  lobalAveragePooling2D)
#
#  dense_20 (Dense)               (None, 1024)         2098176     ['global_average_pooling2d_10[0][
#                                                                  0]']
#
#  dense_21 (Dense)               (None, 10)           10250       ['dense_20[0][0]']
#
# ==================================================================================================
# Total params: 23,911,210
# Trainable params: 2,108,426
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# to fix issue with saving keras applications
K.learning_phase = K.backend.learning_phase

_, (X, Y) = K.datasets.cifar10.load_data()
X_p, Y_p = preprocess_data(X, Y)
model = K.models.load_model("cifar10.h5")
model.evaluate(X_p, Y_p, batch_size=128, verbose=1)
# Out:
# 79/79 [==============================] - 24s 240ms/step - loss: 0.3574 - accuracy: 0.8822
# [0.35742977261543274, 0.8822000026702881]

# %%
import matplotlib.pyplot as plt


# Plot the training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot the training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
